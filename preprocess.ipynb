# %%
import numpy as np
import pandas as pd
import os
from subprocess import check_output
path='data/'
print(check_output(["ls", path]).decode("utf8"))
# Out:
# DRC_Raw_Data 2012-13.xlsx
# DRC_Raw_Data 2013-14.xlsx
# DRC_Raw_Data 2014-15.xlsx
# DRC_Raw_Data 2015-16_new.xlsx
# SEC_SRC_RAW_DATA_2012-13.xlsx
# SEC_SRC_RAW_DATA_2013-14.xlsx
# SEC_SRC_RAW_DATA_2014-15.xlsx
# SEC_SRC_RAW_DATA_2015-16.xlsx
# SRC_Rawdata_2012-13.xlsx
# SRC_Rawdata_2013-14.xlsx
# SRC_Rawdata_2014-15.xlsx
# SRC_Rawdata_2015-16_Elementary.xlsx

# %%
file1=pd.read_excel(path+'DRC_Raw_Data 2012-13.xlsx')

# %%
from glob import glob

# %%
g=glob(path+'*')

# %%
g=sorted(glob(path+'DRC*'))

# %%
g
# Out:
# ['data/DRC_Raw_Data 2012-13.xlsx',
#  'data/DRC_Raw_Data 2013-14.xlsx',
#  'data/DRC_Raw_Data 2014-15.xlsx',
#  'data/DRC_Raw_Data 2015-16_new.xlsx']

# %%
df_state4p3=xl.parse(2,skiprows=3)
df_state4p3.head()
# Out:
#   Unnamed: 0  DISTCD       State Name  DISTNAME  SCH1  SCH2  SCH3  SCH4  SCH5  \
# 0    2014-15     101  JAMMU & KASHMIR   KUPWARA  1099   811     3    14     2
# 1    2014-15     102  JAMMU & KASHMIR  BARAMULA  1205   829     8    11     5
# 2    2014-15     103  JAMMU & KASHMIR  SRINAGAR   253   405    46     2     2
# 3    2014-15     104  JAMMU & KASHMIR    BADGAM   750   535     9    10     1
# 4    2014-15     105  JAMMU & KASHMIR   PULWAMA   544   347     4    13     2
#
#    SCH6  ...   C9_B   C1_G   C2_G   C3_G   C4_G   C5_G   C6_G  C7_G   C8_G  \
# 0    84  ...   6376  10368   8665   8543   7807   7229   6324  6111   6480
# 1   170  ...   8029  18126  11291  10873  10104  10015  10163  9595  10085
# 2   257  ...   6433   8422   7984   8032   7957   7717   7315  7274   7435
# 3   101  ...   5070   7077   6186   6051   5758   5439   5051  5103   5208
# 4    88  ...   3753   4438   3849   3891   3750   3567   3476  3457   3539
#
#    C9_G
# 0  5745
# 1  7430
# 2  6576
# ...

# %%
xl=pd.ExcelFile(g[3])
df_state4p1=xl.parse(0,skiprows=2)
df_state4p1.head()
# Out:
#   Unnamed: 0  STATCD  DISTCD         STATNAME  DISTNAME  DISTRICTS  BLOCKS  \
# 0    2015-16       1     101  JAMMU & KASHMIR   KUPWARA          1      13
# 1    2015-16       1     102  JAMMU & KASHMIR  BARAMULA          1      18
# 2    2015-16       1     103  JAMMU & KASHMIR  SRINAGAR          1       8
# 3    2015-16       1     104  JAMMU & KASHMIR    BADGAM          1      13
# 4    2015-16       1     105  JAMMU & KASHMIR   PULWAMA          1       8
#
#    VILLAGES  CLUSTERS  TOTPOPULAT   ...    TCH_TRNRF6  TCH_TRNRF7  PGRMTCH  \
# 0       391       104    875564.0   ...             1           0     2385
# 1       678       144   1015503.0   ...            11          12     3478
# 2        94        65   1269751.0   ...            16           0      481
# 3       523       104    735753.0   ...             0           0     2309
# 4       359        64    570060.0   ...             1          10     1660
#
#    PGRFTCH  GRMTCH  GRFTCH  PGCMTCH  PGCFTCH  PCMTCH  PCFTCH
# ...

# %%
df_state4.head()
# Out:
#   Unnamed: 0  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0    2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1    2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2    2015-16       3            PUNJAB         22     146     13197      1780
# 3    2015-16       4        CHANDIGARH          1      20        84        20
# 4    2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6     ...      TCH_TRNRM5  TCH_TRNRM6  \
# 0       12549      20.05           16.01     ...               8         328
# 1        6857       8.69           11.14     ...             995           6
# 2       27704      29.82           10.62     ...            2215          13
# 3        1055      97.25           11.18     ...               0         109
# 4       10117      21.54           13.14     ...            1088           0
#
# ...

# %%
df_state4p2p2 = pd.read_excel(g[0], header=[0,1],sheetname='PAGE2 PART2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-6e02dbe0a35c> in <module>()
# ----> 1 df_state4p2p2 = pd.read_excel(g[0], header=[0,1],sheetname='PAGE2 PART2')
#
# /usr/local/lib/python2.7/dist-packages/pandas/io/excel.pyc in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, true_values, false_values, engine, squeeze, **kwds)
#     198         skip_footer=skip_footer, converters=converters,
#     199         true_values=true_values, false_values=false_values, squeeze=squeeze,
# --> 200         **kwds)
#     201
#     202
#
# ...

# %%
df_state4p2p1.head()
# Out:
# statcd           statname  ac_year Schools with Internet             \
# statcd           statname  ac_year            internet_1 internet_2
# 1       Jammu And Kashmir  2014-15                   262         21
# 2        Himachal Pradesh  2014-15                   438        876
# 3                  Punjab  2014-15                  2020       1703
# 4              Chandigarh  2014-15                    83          5
# 5             Uttarakhand  2014-15                   361        642
#
# statcd                                                                      \
# statcd internet_3 internet_4 internet_5 internet_6 internet_7 internet_all
# 1             403          6          0         65          0          757
# 2             342        127          0          6          3         1792
# 3            1596       1832          3         37         72         7263
# 4              65          0          0          0          0          153
# ...

# %%
enum_state=df_dict['Unnamed: 1_level_0']['statname']

# %%
# Out:
# 0                         INDIA
# 1             JAMMU AND KASHMIR
# 2              HIMACHAL PRADESH
# 3                        PUNJAB
# 4                    CHANDIGARH
# 5                   UTTARAKHAND
# 6                       HARYANA
# 7                         DELHI
# 8                     RAJASTHAN
# 9                 UTTAR PRADESH
# 10                        BIHAR
# 11                       SIKKIM
# 12            ARUNACHAL PRADESH
# 13                     NAGALAND
# 14                      MANIPUR
# 15                      MIZORAM
# 16                      TRIPURA
# 17                    MEGHALAYA
# 18                        ASSAM
# 19                  WEST BENGAL
# 20                    JHARKHAND
# 21                       ODISHA
# 22                 CHHATTISGARH
# 23               MADHYA PRADESH
# 24                      GUJARAT
# 25                  DAMAN & DIU
# 26         DADRA & NAGAR HAVELI
# 27                  MAHARASHTRA
# 28               ANDHRA PRADESH
# ...

# %%
xl=pd.ExcelFile(g[1])

# %%
df1=xl.parse(0)

# %%
df1.head(10)
# Out:
#                                        Area Total Population  \
# statcd ac_year statname           area_sqkm   tot_population
# 00     2012-13 INDIA                3287240      1.21019e+06
# 01     2012-13 JAMMU AND KASHMIR     222236          12548.9
# 02     2012-13 HIMACHAL PRADESH       55673          6856.51
# 03     2012-13 PUNJAB                 50362          27704.2
# 04     2012-13 CHANDIGARH               114          1054.69
# 05     2012-13 UTTARAKHAND            53483          10116.8
# 06     2012-13 HARYANA                44212          25353.1
# 07     2012-13 DELHI                   1483          16753.2
# 08     2012-13 RAJASTHAN             342239            68621
#
#                                   Urban Population  Growth Rate Sex Ratio  \
# statcd ac_year statname           urban_population  grwoth_rate  sexratio
# 00     2012-13 INDIA                          31.2        17.64       940
# ...

# %%
df_state4p2[:680].shape
# Out:
# (680, 384)

# %%
df_state4p2.tail()
# Out:
#      Unnamed: 0  DISTCD STATNAME DISTNAME  C1_B  C2_B  C3_B  C4_B  C5_B  C6_B  \
# 1358        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1359        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1360        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1361        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1362        NaN     NaN      NaN      NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#         ...     UUNI_ALL  UUNI_SC  UUNI_ST  TOTCLS1G  TOTCLS2G  TOTCLS3G  \
# 1358    ...          NaN      NaN      NaN       NaN       NaN       NaN
# 1359    ...          NaN      NaN      NaN       NaN       NaN       NaN
# 1360    ...          NaN      NaN      NaN       NaN       NaN       NaN
# 1361    ...          NaN      NaN      NaN       NaN       NaN       NaN
# 1362    ...          NaN      NaN      NaN       NaN       NaN       NaN
#
#       TOTCLS4G  TOTCLS5G  TOTCLS6G  TOTCLS7G
# ...

# %%
temp=np.hstack((df_state4p1.values,df_state4p2[:680].values,df_state4p3.values))

# %%
temp.shape
column_n=[]

# %%
n=len(df_state4p3.columns)
for i in range(0,n):
    column_n.append(df_state4p3.columns[i])
column_n
# Out:
# ['Unnamed: 0',
#  u'STATCD',
#  u'DISTCD',
#  u'STATNAME',
#  u'DISTNAME',
#  u'DISTRICTS',
#  u'BLOCKS',
#  u'VILLAGES',
#  u'CLUSTERS',
#  u'TOTPOPULAT',
#  u'P_URB_POP',
#  u'POPULATION_0_6',
#  u'GROWTHRATE',
#  u'SEXRATIO',
#  u'P_SC_POP',
#  u'P_ST_POP',
#  u'OVERALL_LI',
#  u'FEMALE_LIT',
#  u'MALE_LIT',
#  u'AREA_SQKM',
#  u'TOT_6_10_15',
#  u'TOT_11_13_15',
#  u'SCH1',
#  u'SCH2',
#  u'SCH3',
#  u'SCH4',
#  u'SCH5',
#  u'SCH6',
#  u'SCH7',
#  u'SCH9',
#  u'SCHTOT',
#  u'SCH1G',
#  u'SCH2G',
#  u'SCH3G',
#  u'SCH4G',
#  u'SCH5G',
#  u'SCH6G',
#  u'SCH7G',
#  u'SCH9G',
#  u'SCHTOTG',
#  u'SCH1P',
#  u'SCH2P',
#  u'SCH3P',
#  u'SCH4P',
#  u'SCH5P',
#  u'SCH6P',
#  u'SCH7P',
#  u'SCH9P',
#  u'SCHTOTP',
#  u'SCH1M',
#  u'SCH2M',
#  u'SCH3M',
#  u'SCH4M',
#  u'SCH5M',
#  u'SCH6M',
#  u'SCH7M',
#  u'SCH9M',
#  u'SCHTOTM',
#  u'SCH1GR',
#  u'SCH2GR',
#  u'SCH3GR',
#  u'SCH4GR',
#  u'SCH5GR',
#  u'SCH6GR',
#  u'SCH7GR',
#  u'SCH9GR',
#  u'SCHTOTGR',
#  u'SCH1GA',
#  u'SCH2GA',
# ...

# %%
len(column_n)
# Out:
# 1079

# %%
all4=pd.DataFrame(temp)
all4.head()
# Out:
#       0    1    2                3         4    5    6    7    8     \
# 0  2015-16    1  101  JAMMU & KASHMIR   KUPWARA    1   13  391  104
# 1  2015-16    1  102  JAMMU & KASHMIR  BARAMULA    1   18  678  144
# 2  2015-16    1  103  JAMMU & KASHMIR  SRINAGAR    1    8   94   65
# 3  2015-16    1  104  JAMMU & KASHMIR    BADGAM    1   13  523  104
# 4  2015-16    1  105  JAMMU & KASHMIR   PULWAMA    1    8  359   64
#
#           9     ...   1069   1070   1071   1072   1073   1074   1075  1076  \
# 0       875564  ...   6376  10368   8665   8543   7807   7229   6324  6111
# 1   1.0155e+06  ...   8029  18126  11291  10873  10104  10015  10163  9595
# 2  1.26975e+06  ...   6433   8422   7984   8032   7957   7717   7315  7274
# 3       735753  ...   5070   7077   6186   6051   5758   5439   5051  5103
# 4       570060  ...   3753   4438   3849   3891   3750   3567   3476  3457
#
#     1077  1078
# 0   6480  5745
# 1  10085  7430
# 2   7435  6576
# 3   5208  5098
# 4   3539  3479
#
# ...

# %%
all4.columns=column_n

# %%
all4.head()
# Out:
#   Unnamed: 0 STATCD DISTCD         STATNAME  DISTNAME DISTRICTS BLOCKS  \
# 0    2015-16      1    101  JAMMU & KASHMIR   KUPWARA         1     13
# 1    2015-16      1    102  JAMMU & KASHMIR  BARAMULA         1     18
# 2    2015-16      1    103  JAMMU & KASHMIR  SRINAGAR         1      8
# 3    2015-16      1    104  JAMMU & KASHMIR    BADGAM         1     13
# 4    2015-16      1    105  JAMMU & KASHMIR   PULWAMA         1      8
#
#   VILLAGES CLUSTERS   TOTPOPULAT  ...   C9_B   C1_G   C2_G   C3_G   C4_G  \
# 0      391      104       875564  ...   6376  10368   8665   8543   7807
# 1      678      144   1.0155e+06  ...   8029  18126  11291  10873  10104
# 2       94       65  1.26975e+06  ...   6433   8422   7984   8032   7957
# 3      523      104       735753  ...   5070   7077   6186   6051   5758
# 4      359       64       570060  ...   3753   4438   3849   3891   3750
#
#     C5_G   C6_G  C7_G   C8_G  C9_G
# 0   7229   6324  6111   6480  5745
# ...

# %%
all4.to_csv('year4.csv')

# %%
all4.shape
# Out:
# (680, 1079)

# %%
b=all4.T.drop_duplicates().T
b.shape
# Out:
# (680, 1049)

# %%
b=b.fillna(0)
b.to_csv('year4_fixed.csv')
